# %% [markdown]
# # RFC obtaintion
# In this document RFCs from different files are obtained. The goal is to concactenate many tables (with 2 columns only: "RFC" and "Razón social"), validate RFCs and clean column "Razón social" by applying Regex techniques.

# %%
# Import libraries
import pandas as pd

# %%
# Create DataFrame from CSV file
csv_file = 'SAT_CFDIS_2020_Emisor.csv'
df = pd.read_csv(csv_file, sep=',', header=None, names=['RFC','Razón social'])
print(df.head(3))
# Out:
#             RFC                             Razón social
# 0  AAA000613UW0                         AAATEC, SA DE CV
# 1  AAA100125UX6       ARQUITECTOS ADM AMBIENTAL SA DE CV
# 2  AAA100721MF7  ACERO Y ALUMINIO DE APASEO S.A. DE C.V.
